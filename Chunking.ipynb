# %% [markdown]
# # Chunking

# %%
import nltk

# %%
# take sentence, tokenize and pos tag it.
# text="""IMDB dataset having 50K movie reviews for natural language processing or Text analytics.
# This is a dataset for binary sentiment classification containing substantially more data than previous benchmark datasets. We provide a set of 25,000 highly polar movie reviews for training and 25,000 for testing. So, predict the number of positive and negative reviews using either classification or deep learning algorithms."""
# words=nltk.word_tokenize(text)
# print(words)
# tagged=nltk.pos_tag(words)
# print(tagged)

grammar="NP:{<DT>?<JJ>*<NN>}"

cp=nltk.RegexpParser(grammar)
texts=["""Born and raised in central Argentina, Messi relocated to Spain at the age of 13 to join Barcelona, for whom he made his competitive debut aged 17 in October 2004. He established himself as an integral player for the club within the next three years, and in his first uninterrupted season in 2008–09 he helped Barcelona achieve the first treble in Spanish football; that year, aged 22, Messi won his first Ballon d'Or. Three successful seasons followed, with Messi winning four consecutive Ballons d'Or, making him the first player to win the award four times."""]
for text in texts:
    sentences=nltk.sent_tokenize(text)
    for sentence in sentences:
        words=nltk.word_tokenize(sentence)
#         print(words)
        tagged=nltk.pos_tag(words)
#         print(tagged)
        result=cp.parse(tagged)
        print(result)
# Out:
# (S
#   Born/NNP
#   and/CC
#   raised/VBN
#   in/IN
#   central/JJ
#   Argentina/NNP
#   ,/,
#   Messi/NNP
#   relocated/VBD
#   to/TO
#   Spain/NNP
#   at/IN
#   (NP the/DT age/NN)
#   of/IN
#   13/CD
#   to/TO
#   join/VB
#   Barcelona/NNP
#   ,/,
#   for/IN
#   whom/WP
#   he/PRP
#   made/VBD
#   his/PRP$
#   (NP competitive/JJ debut/NN)
#   aged/VBD
#   17/CD
#   in/IN
#   October/NNP
#   2004/CD
#   ./.)
# (S
#   He/PRP
#   established/VBD
#   himself/PRP
#   as/IN
#   (NP an/DT integral/JJ player/NN)
#   for/IN
#   (NP the/DT club/NN)
#   within/IN
#   the/DT
#   next/JJ
#   three/CD
#   years/NNS
#   ,/,
#   and/CC
#   in/IN
#   his/PRP$
#   (NP first/JJ uninterrupted/JJ season/NN)
#   in/IN
#   2008–09/CD
#   he/PRP
#   helped/VBD
#   Barcelona/NNP
#   achieve/VB
#   the/DT
#   first/JJ
#   treble/JJ
#   in/IN
#   (NP Spanish/JJ football/NN)
#   ;/:
#   that/IN
#   (NP year/NN)
#   ,/,
#   aged/VBD
#   22/CD
#   ,/,
#   Messi/NNP
#   won/VBD
#   his/PRP$
#   first/JJ
#   Ballon/NNP
#   (NP d'Or/NN)
#   ./.)
# (S
#   Three/CD
#   successful/JJ
#   seasons/NNS
#   followed/VBD
#   ,/,
#   with/IN
#   Messi/NNP
#   winning/VBG
#   four/CD
#   consecutive/JJ
#   Ballons/NNP
#   (NP d'Or/NN)
#   ,/,
#   making/VBG
#   him/PRP
#   (NP the/DT first/JJ player/NN)
#   to/TO
#   win/VB
#   (NP the/DT award/NN)
#   four/CD
#   times/NNS
#   ./.)

# %%
# grammar="NP:{<DT>?<JJ>*<NN>}"

# cp=nltk.RegexpParser(grammar)
# result=cp.parse(tagged)
# print(result)
